# %%
import numpy as np
import pandas as pd
import os
import time

# Define the path to the folder containing the subfolders
data_folder = r"LeadV1 Mix"

# Define the Q-learning parameters
num_actions = 5
alpha = 0.01
gamma = 0.9
epsilon = 0.1
num_episodes = 100

# Define the accuracy function
def get_accuracy(num_correct, num_beats, total_confidence):
    accuracy = num_correct / num_beats
    confidence = total_confidence / num_beats
    return accuracy, confidence

# Define the softmax function
def softmax(x):
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum(axis=0)

# Define the Q-learning function
def q_learning(df, num_states):
    # Initialize the Q-table
    Q = np.zeros((num_states, num_actions))

    # Define the state function
    def get_state(row):
        state = int(row['Beat_Number']) - 1 # Subtract 1 to convert to zero-based index
        return state

    # Define the action function
    def get_action(state):
        if np.random.uniform(0, 1) < epsilon:
            # Choose a random action
            action = np.random.randint(num_actions)
        else:
            # Choose the action with the highest Q-value
            action = np.argmax(Q[state])
        confidence = softmax(Q[state])[action]
        return action, confidence
    
    # Initialize the number of correct classifications
    num_correct = 0
    num_beats = 0
    total_confidence = 0

    # Loop through the episodes
    for episode in range(num_episodes):
        start_time = time.time()
        # Reset the state to the beginning of the file
        state = 0

        # Initialize the total reward for the episode
        total_reward = 0

        # Initialize the time taken for classification
        time_taken = 0

        # Loop through the rows of the dataframe
        for i, row in df.iterrows():
            # Get the current state and action
            state = get_state(row)
            action, confidence = get_action(state)

            # Get the reward for the current action
            reward = 0
            if row['Diagnostic_Label'] == action:
                # Give a reward of 1 for accurate classification
                reward = 1
                num_correct += 1
            else:
                # Give a reward of -1 for misclassification
                reward = -1

            # Calculate the time taken for classification
            start_time = time.time()
            next_state = get_state(df.iloc[i+1]) if i+1 < len(df) else state
            end_time = time.time()
            time_taken += end_time - start_time

            # Add a negative penalty to the reward based on the time taken for classification
            reward -= time_taken

            # Update the Q-value for the current state-action pair
            Q[state, action] = Q[state, action] + alpha * (reward + gamma * np.max(Q[next_state]) - Q[state, action])

            # Update the state and total reward
            state = next_state
            total_reward += reward + confidence
            # Update the total beats
            num_beats += 1
            total_confidence += confidence

        # Print the total reward and accuracy for the episode
        accuracy = get_accuracy(num_correct, num_beats, total_confidence)
        print("Episode {}: Total Reward = {}, Accuracy = {:.2f}, Confidence Probability = {:.2f}, Time of Classification = {:.4f} seconds".format(episode+1, total_reward, accuracy[0], accuracy[1], time_taken))

       # Print the Q-table
        print("Q-table:")
        print(Q)

    # Return the Q-table
    return Q


# Initialize an empty list to store the Q-tables
Q_list = []


# Loop through each subfolder and read in the CSV files
for subdir in os.listdir(data_folder):
    subfolder_path = os.path.join(data_folder, subdir)
    if os.path.isdir(subfolder_path):
        for file in os.listdir(subfolder_path):
            file_path = os.path.join(subfolder_path, file)
            if file_path.endswith(".csv"):
                # Read in the CSV file
                df = pd.read_csv(file_path)

                # Drop in the NaN values in the 'Beat_Number' column 
                #print(df['Beat_Number'].isnull().sum())
                df = df.dropna(subset=['Beat_Number'])

                # Check if the 'Beat_Number' column exists in the dataframe
                if 'Beat_Number' in df.columns:
                    # Group the dataframe by Beat_Number and drop the Beat_Number column
                    df = df.groupby('Beat_Number').first().reset_index()
                    df = df[['Time_Samples', 'LeadV1', 'R_Peaks', 'Diagnostic_Label','Beat_Number']]

                    # Set the number of states to be equal to the number of beats
                    num_states = df.shape[0]

                    # Run Q-learning on the dataframe
                    Q = q_learning(df, num_states)
                    policy = np.argmax(Q, axis=1)
                    print(policy)
                    Q_list.append(Q)

avg_Q_table = np.vstack(Q_list).mean(axis=0)
print(avg_Q_table)
# Out:
# Episode 1: Total Reward = -310.45892610550135, Accuracy = 0.01, Confidence Probability = 0.20, Time of Classification = 0.1095 seconds
# Q-table:
# [[-0.01        0.          0.          0.          0.        ]
#  [-0.01        0.          0.          0.          0.        ]
#  [-0.01        0.          0.          0.          0.        ]
#  ...
#  [-0.01109451  0.          0.          0.          0.        ]
#  [-0.01109451  0.          0.          0.          0.        ]
#  [-0.01109451  0.          0.          0.          0.        ]]
# Episode 2: Total Reward = -298.8629457974194, Accuracy = 0.02, Confidence Probability = 0.20, Time of Classification = 0.0787 seconds
# Q-table:
# [[-0.01       -0.01        0.          0.          0.        ]
#  [-0.01       -0.01        0.          0.          0.        ]
#  [-0.0199      0.          0.          0.          0.        ]
#  ...
#  [-0.01109451 -0.0107875   0.          0.          0.        ]
#  [-0.01109451 -0.0107875   0.          0.          0.        ]
#  [-0.01109451 -0.0107875   0.          0.          0.        ]]
# Episode 3: Total Reward = -284.254346961156, Accuracy = 0.02, Confidence Probability = 0.20, Time of Classification = 0.0683 seconds
# Q-table:
# [[-0.01       -0.01       -0.01        0.          0.        ]
#  [-0.01       -0.01       -0.01015627  0.          0.        ]
#  [-0.0199     -0.01015627  0.          0.          0.        ]
#  ...
#  [-0.01109451 -0.0107875  -0.01068331  0.          0.        ]
#  [-0.01109451 -0.0107875  -0.01068331  0.          0.        ]
#  [-0.01109451 -0.0107875  -0.01068331  0.          0.        ]]
# Episode 4: Total Reward = -266.7833430966243, Accuracy = 0.03, Confidence Probability = 0.20, Time of Classification = 0.0806 seconds
# Q-table:
# [[-0.01       -0.01       -0.01       -0.01        0.        ]
#  [-0.01       -0.01       -0.01015627 -0.01        0.        ]
#  [-0.0199     -0.01015627 -0.01        0.          0.        ]
#  ...
#  [-0.01109451 -0.0107875  -0.01068331 -0.01080586  0.        ]
#  [-0.01109451 -0.0107875  -0.01068331 -0.01080586  0.        ]
#  [-0.01109451 -0.0107875  -0.01068331 -0.01080586  0.        ]]
# Episode 5: Total Reward = 301.4009955324827, Accuracy = 0.19, Confidence Probability = 0.20, Time of Classification = 0.0958 seconds
# Q-table:
# [[-0.01       -0.01       -0.01       -0.01        0.01      ]
#  [-0.01       -0.01       -0.01015627 -0.01        0.01      ]
#  [-0.0199     -0.01015627 -0.01       -0.01        0.        ]
#  ...
#  [-0.01109451 -0.0107875  -0.01068331 -0.01080586  0.00904227]
#  [-0.01109451 -0.02163735 -0.01068331 -0.01080586  0.        ]
#  [-0.01109451 -0.0107875  -0.01068331 -0.01080586  0.00904227]]
# Episode 6: Total Reward = 390.9973313661102, Accuracy = 0.32, Confidence Probability = 0.20, Time of Classification = 0.1047 seconds
# Q-table:
# [[-0.01       -0.01       -0.01       -0.01        0.01999   ]
#  [-0.01       -0.01       -0.01015627 -0.01        0.0199    ]
#  [-0.0199     -0.01015627 -0.01       -0.01        0.0100916 ]
#  ...
#  [-0.01109451 -0.0107875  -0.01068331 -0.01080586  0.01790475]
#  [-0.01109451 -0.02163735 -0.01068331 -0.01080586  0.00903428]
#  [-0.01109451 -0.0107875  -0.01068331 -0.01080586  0.01798613]]
# Episode 7: Total Reward = 380.79171663353503, Accuracy = 0.41, Confidence Probability = 0.20, Time of Classification = 0.1093 seconds
# Q-table:
# [[-0.01       -0.01       -0.01       -0.01        0.0299692 ]
#  [-0.01       -0.01       -0.01015627 -0.01        0.02979182]
#  [-0.0199     -0.01015627 -0.01       -0.01        0.02017376]
#  ...
#  [-0.01109451 -0.0107875  -0.01068331 -0.01080586  0.02671414]
#  [-0.01109451 -0.02163735 -0.01068331 -0.01080586  0.01801294]
#  [-0.01109451 -0.0107875  -0.01068331 -0.01080586  0.02687527]]
# Episode 8: Total Reward = 365.1594690655617, Accuracy = 0.47, Confidence Probability = 0.20, Time of Classification = 0.0486 seconds
# Q-table:
# [[-0.01       -0.01       -0.01963187 -0.01        0.0299692 ]
#  [-0.01       -0.01       -0.01015627 -0.01        0.03967547]
#  [-0.02951792 -0.01015627 -0.01       -0.01        0.02017376]
#  ...
#  [-0.01109451 -0.0107875  -0.01068331 -0.01080586  0.03612341]
#  [-0.01109451 -0.02163735 -0.01068331 -0.01080586  0.02758899]
#  [-0.01109451 -0.0107875  -0.01068331 -0.02094162  0.02687527]]
# Episode 9: Total Reward = 376.1522842988457, Accuracy = 0.52, Confidence Probability = 0.20, Time of Classification = 0.0689 seconds
# Q-table:
# [[-0.01       -0.01       -0.01963187 -0.01        0.04002659]
#  [-0.01       -0.01       -0.01015627 -0.01        0.04946028]
#  [-0.02951792 -0.01015627 -0.01       -0.01        0.03024723]
#  ...
#  [-0.01109451 -0.0107875  -0.01068331 -0.01080586  0.04532123]
#  [-0.01109451 -0.02163735 -0.01068331 -0.01080586  0.03686573]
#  [-0.01109451 -0.0107875  -0.01068331 -0.02094162  0.03615915]]
# Episode 10: Total Reward = 357.68417681488944, Accuracy = 0.56, Confidence Probability = 0.20, Time of Classification = 0.1068 seconds
# Q-table:
# [[-0.01       -0.01       -0.01963187 -0.01        0.05007146]
#  [-0.01       -0.01       -0.01015627 -0.01        0.0592379 ]
#  [-0.02951792 -0.01015627 -0.01       -0.01        0.04031197]
#  ...
#  [-0.01109451 -0.0107875  -0.02131298 -0.01080586  0.04532123]
#  [-0.01109451 -0.02163735 -0.01068331 -0.01080586  0.0457542 ]
#  [-0.01109451 -0.0107875  -0.01068331 -0.02094162  0.04505469]]
# Episode 11: Total Reward = 392.240583640572, Accuracy = 0.59, Confidence Probability = 0.20, Time of Classification = 0.0534 seconds
# Q-table:
# [[-0.01       -0.01       -0.01963187 -0.01        0.06010389]
#  [-0.01       -0.01       -0.01015627 -0.01        0.06900833]
#  [-0.02951792 -0.01015627 -0.01       -0.01        0.05036792]
#  ...
#  [-0.01109451 -0.0107875  -0.02131298 -0.01080586  0.05474564]
#  [-0.01109451 -0.02163735 -0.01068331 -0.01080586  0.05516799]
#  [-0.01109451 -0.0107875  -0.01068331 -0.02094162  0.05447547]]
# Episode 12: Total Reward = 372.7810426358767, Accuracy = 0.62, Confidence Probability = 0.20, Time of Classification = 0.1280 seconds
# Q-table:
# [[-0.01       -0.01       -0.01963187 -0.01927893  0.06010389]
#  [-0.01       -0.01       -0.01015627 -0.01        0.07877156]
#  [-0.02951792 -0.01015627 -0.01       -0.01        0.06041504]
#  ...
#  [-0.01109451 -0.0107875  -0.02131298 -0.01080586  0.06341424]
#  [-0.01109451 -0.02163735 -0.01068331 -0.01080586  0.06382613]
#  [-0.01109451 -0.0107875  -0.01068331 -0.02094162  0.06314053]]
# Episode 13: Total Reward = 369.64515430289447, Accuracy = 0.64, Confidence Probability = 0.20, Time of Classification = 0.0572 seconds
# Q-table:
# [[-0.01       -0.01       -0.01963187 -0.01927893  0.0702118 ]
#  [-0.01       -0.01       -0.01015627 -0.01        0.08852758]
#  [-0.02951792 -0.01941232 -0.01       -0.01        0.06041504]
#  ...
#  [-0.01109451 -0.0107875  -0.02131298 -0.01080586  0.07278222]
#  [-0.01109451 -0.02163735 -0.01068331 -0.01080586  0.07318381]
#  [-0.01109451 -0.0107875  -0.01068331 -0.02094162  0.07250507]]
# Episode 14: Total Reward = 380.63754476034563, Accuracy = 0.66, Confidence Probability = 0.21, Time of Classification = 0.0943 seconds
# Q-table:
# [[-0.01       -0.01       -0.01963187 -0.01927893  0.08030643]
#  [-0.01       -0.01       -0.01015627 -0.01        0.09818604]
#  [-0.02951792 -0.01941232 -0.01       -0.01        0.07054474]
#  ...
#  [-0.01109451 -0.0107875  -0.02131298 -0.01080586  0.08177052]
#  [-0.01109451 -0.02163735 -0.01068331 -0.01080586  0.08216199]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.07250507]]
# Episode 15: Total Reward = 359.71310220551993, Accuracy = 0.68, Confidence Probability = 0.21, Time of Classification = 0.0932 seconds
# Q-table:
# [[-0.01       -0.01       -0.01963187 -0.01927893  0.09038704]
#  [-0.01       -0.01       -0.01015627 -0.01        0.10783908]
#  [-0.02951792 -0.01941232 -0.01       -0.01        0.0806637 ]
#  ...
#  [-0.01109451 -0.0107875  -0.02131298 -0.01080586  0.09076071]
#  [-0.01109451 -0.02163735 -0.01068331 -0.01080586  0.09106135]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.081501  ]]
# Episode 16: Total Reward = 355.1663068149479, Accuracy = 0.69, Confidence Probability = 0.21, Time of Classification = 0.1101 seconds
# Q-table:
# [[-0.01       -0.01       -0.01963187 -0.01927893  0.10045372]
#  [-0.01933026 -0.01       -0.01015627 -0.01        0.10783908]
#  [-0.02951792 -0.01941232 -0.01       -0.01        0.09061566]
#  ...
#  [-0.01109451 -0.0107875  -0.02131298 -0.02097934  0.09076071]
#  [-0.01109451 -0.02163735 -0.01068331 -0.02106538  0.09106135]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.09031841]]
# Episode 17: Total Reward = 370.71572687293354, Accuracy = 0.70, Confidence Probability = 0.21, Time of Classification = 0.1090 seconds
# Q-table:
# [[-0.01       -0.01       -0.01963187 -0.01927893  0.11041973]
#  [-0.01933026 -0.01       -0.01015627 -0.01        0.11757623]
#  [-0.02951792 -0.01941232 -0.01       -0.01        0.10071245]
#  ...
#  [-0.01109451 -0.0107875  -0.02131298 -0.02097934  0.09958223]
#  [-0.01109451 -0.02163735 -0.01068331 -0.02106538  0.09987318]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.09913767]]
# Episode 18: Total Reward = 379.3271077818397, Accuracy = 0.72, Confidence Probability = 0.21, Time of Classification = 0.0694 seconds
# Q-table:
# [[-0.01       -0.01       -0.01963187 -0.01927893  0.12037372]
#  [-0.01933026 -0.01       -0.01015627 -0.01        0.12730688]
#  [-0.02951792 -0.01941232 -0.01       -0.01        0.1107977 ]
#  ...
#  [-0.01109451 -0.0107875  -0.02131298 -0.02097934  0.10879094]
#  [-0.01109451 -0.02163735 -0.01068331 -0.02106538  0.10907236]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.1083442 ]]
# Episode 19: Total Reward = 369.475149473856, Accuracy = 0.73, Confidence Probability = 0.21, Time of Classification = 0.1033 seconds
# Q-table:
# [[-0.01       -0.01       -0.01963187 -0.01927893  0.13031575]
#  [-0.01933026 -0.01       -0.01015627 -0.01        0.13703099]
#  [-0.02951792 -0.01941232 -0.01       -0.01        0.12087144]
#  ...
#  [-0.01109451 -0.0107875  -0.02131298 -0.02097934  0.1176519 ]
#  [-0.01109451 -0.02163735 -0.01068331 -0.02106538  0.11792396]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.11720308]]
# Episode 20: Total Reward = 367.5582012749815, Accuracy = 0.74, Confidence Probability = 0.21, Time of Classification = 0.0945 seconds
# Q-table:
# [[-0.01       -0.01       -0.01963187 -0.01927893  0.14024587]
#  [-0.01933026 -0.01       -0.01015627 -0.01        0.14674852]
#  [-0.02951792 -0.01941232 -0.01       -0.01        0.13093366]
#  ...
#  [-0.01109451 -0.0107875  -0.0309835  -0.02097934  0.1176519 ]
#  [-0.01109451 -0.02163735 -0.01068331 -0.02106538  0.12685458]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.12614092]]
# Episode 21: Total Reward = 381.42677038568684, Accuracy = 0.74, Confidence Probability = 0.21, Time of Classification = 0.1006 seconds
# Q-table:
# [[-0.01       -0.01       -0.01963187 -0.01927893  0.15016414]
#  [-0.01933026 -0.01       -0.01015627 -0.01        0.15645944]
#  [-0.0379518  -0.01941232 -0.01       -0.01        0.13093366]
#  ...
#  [-0.01109451 -0.0107875  -0.0309835  -0.02097934  0.12661075]
#  [-0.01109451 -0.02163735 -0.01068331 -0.02106538  0.13571498]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.13500845]]
# Episode 22: Total Reward = 377.2620810923171, Accuracy = 0.75, Confidence Probability = 0.21, Time of Classification = 0.1059 seconds
# Q-table:
# [[-0.01       -0.01       -0.01963187 -0.01927893  0.16007064]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.15645944]
#  [-0.0379518  -0.01941232 -0.01       -0.01        0.14098514]
#  ...
#  [-0.01109451 -0.0107875  -0.0309835  -0.02097934  0.13550737]
#  [-0.01109451 -0.02163735 -0.01068331 -0.02106538  0.1445142 ]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.14381473]]
# Episode 23: Total Reward = 388.5186663301306, Accuracy = 0.76, Confidence Probability = 0.21, Time of Classification = 0.0755 seconds
# Q-table:
# [[-0.01       -0.01       -0.01963187 -0.01927893  0.16987807]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.16616371]
#  [-0.0379518  -0.01941232 -0.01       -0.01        0.15102591]
#  ...
#  [-0.01109451 -0.0107875  -0.0309835  -0.02097934  0.14469803]
#  [-0.01109451 -0.02163735 -0.01068331 -0.02106538  0.15360849]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.15291602]]
# Episode 24: Total Reward = 386.8485822358434, Accuracy = 0.77, Confidence Probability = 0.21, Time of Classification = 0.0710 seconds
# Q-table:
# [[-0.01       -0.01       -0.01963187 -0.01927893  0.17967476]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.17586131]
#  [-0.0379518  -0.01941232 -0.01       -0.01        0.16105518]
#  ...
#  [-0.01109451 -0.0107875  -0.0309835  -0.02097934  0.1539234 ]
#  [-0.01109451 -0.02163735 -0.01068331 -0.02106538  0.16273853]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.16205298]]
# Episode 25: Total Reward = 350.11456746676714, Accuracy = 0.77, Confidence Probability = 0.21, Time of Classification = 0.1313 seconds
# Q-table:
# [[-0.01       -0.01       -0.01963187 -0.01927893  0.18934014]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.18543157]
#  [-0.0379518  -0.01941232 -0.01       -0.01        0.17095235]
#  ...
#  [-0.01109451 -0.0107875  -0.0309835  -0.02097934  0.16253555]
#  [-0.01109451 -0.02163735 -0.01068331 -0.02106538  0.17125636]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.17057767]]
# Episode 26: Total Reward = 371.48165054546644, Accuracy = 0.78, Confidence Probability = 0.21, Time of Classification = 0.1104 seconds
# Q-table:
# [[-0.01       -0.01       -0.01963187 -0.01927893  0.19911563]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.19511583]
#  [-0.0379518  -0.01941232 -0.01       -0.01        0.18091806]
#  ...
#  [-0.01109451 -0.0107875  -0.0309835  -0.02097934  0.17134717]
#  [-0.01109451 -0.02163735 -0.01068331 -0.02106538  0.17997466]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.17930276]]
# Episode 27: Total Reward = 406.2061542942291, Accuracy = 0.78, Confidence Probability = 0.21, Time of Classification = 0.0630 seconds
# Q-table:
# [[-0.01       -0.01       -0.01963187 -0.01927893  0.20888051]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.20479293]
#  [-0.0379518  -0.01941232 -0.01       -0.01        0.19091307]
#  ...
#  [-0.01109451 -0.0107875  -0.0309835  -0.02097934  0.18062396]
#  [-0.01109451 -0.02163735 -0.01959226 -0.02106538  0.17997466]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.18849394]]
# Episode 28: Total Reward = 393.5560777122823, Accuracy = 0.79, Confidence Probability = 0.21, Time of Classification = 0.1204 seconds
# Q-table:
# [[-0.01       -0.01       -0.01963187 -0.01927893  0.21863484]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.21446322]
#  [-0.0379518  -0.01941232 -0.01       -0.01        0.20089089]
#  ...
#  [-0.01109451 -0.0107875  -0.0309835  -0.02097934  0.18923323]
#  [-0.01109451 -0.02163735 -0.01959226 -0.02106538  0.1886671 ]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.19710119]]
# Episode 29: Total Reward = 365.9439809258971, Accuracy = 0.79, Confidence Probability = 0.22, Time of Classification = 0.0949 seconds
# Q-table:
# [[-0.01       -0.01       -0.01963187 -0.01927893  0.22837866]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.2240894 ]
#  [-0.0379518  -0.01941232 -0.01       -0.01        0.2108258 ]
#  ...
#  [-0.01109451 -0.0107875  -0.0309835  -0.02097934  0.19808964]
#  [-0.01109451 -0.02163735 -0.01959226 -0.03003007  0.1886671 ]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.20595483]]
# Episode 30: Total Reward = 383.26482103837867, Accuracy = 0.80, Confidence Probability = 0.22, Time of Classification = 0.0916 seconds
# Q-table:
# [[-0.01       -0.01       -0.01963187 -0.01927893  0.23811168]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.23374593]
#  [-0.0379518  -0.01941232 -0.01       -0.01        0.22078654]
#  ...
#  [-0.01109451 -0.0107875  -0.0309835  -0.02097934  0.20689063]
#  [-0.01109451 -0.02163735 -0.01959226 -0.03003007  0.1977179 ]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.21483275]]
# Episode 31: Total Reward = 400.06554175141554, Accuracy = 0.80, Confidence Probability = 0.22, Time of Classification = 0.0918 seconds
# Q-table:
# [[-0.01       -0.01       -0.01963187 -0.01927893  0.24783428]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.24339555]
#  [-0.0379518  -0.01941232 -0.01       -0.01        0.23073585]
#  ...
#  [-0.01109451 -0.0107875  -0.0309835  -0.02097934  0.2156832 ]
#  [-0.01109451 -0.02163735 -0.01959226 -0.03003007  0.20675624]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.22369994]]
# Episode 32: Total Reward = 387.7772597001226, Accuracy = 0.81, Confidence Probability = 0.22, Time of Classification = 0.1432 seconds
# Q-table:
# [[-0.01       -0.01786947 -0.01963187 -0.01927893  0.24783428]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.25287241]
#  [-0.0379518  -0.01941232 -0.01       -0.01        0.24050795]
#  ...
#  [-0.01109451 -0.0107875  -0.0309835  -0.02097934  0.22395477]
#  [-0.01109451 -0.02163735 -0.02881544 -0.03003007  0.20675624]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.23204384]]
# Episode 33: Total Reward = 382.77557241459385, Accuracy = 0.81, Confidence Probability = 0.22, Time of Classification = 0.0755 seconds
# Q-table:
# [[-0.01       -0.01786947 -0.01963187 -0.01927893  0.25763179]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.26250826]
#  [-0.0379518  -0.01941232 -0.01       -0.01        0.25043461]
#  ...
#  [-0.01109451 -0.0107875  -0.0309835  -0.02097934  0.23282153]
#  [-0.01109451 -0.02163735 -0.02881544 -0.03003007  0.21602256]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.24105729]]
# Episode 34: Total Reward = 399.61084718246576, Accuracy = 0.81, Confidence Probability = 0.22, Time of Classification = 0.1197 seconds
# Q-table:
# [[-0.01       -0.01786947 -0.01963187 -0.01927893  0.26741804]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.27213709]
#  [-0.0379518  -0.01941232 -0.01       -0.01        0.26034987]
#  ...
#  [-0.0202368  -0.0107875  -0.0309835  -0.02097934  0.23282153]
#  [-0.01109451 -0.02163735 -0.02881544 -0.03003007  0.22483441]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.24961879]]
# Episode 35: Total Reward = 370.3255342637853, Accuracy = 0.82, Confidence Probability = 0.22, Time of Classification = 0.1339 seconds
# Q-table:
# [[-0.01       -0.01786947 -0.01963187 -0.01927893  0.2771931 ]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.28175886]
#  [-0.0379518  -0.01941232 -0.01       -0.01        0.27025373]
#  ...
#  [-0.0202368  -0.0107875  -0.0309835  -0.02097934  0.24117809]
#  [-0.01109451 -0.02163735 -0.02881544 -0.03003007  0.23349391]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.25803044]]
# Episode 36: Total Reward = 371.930717045651, Accuracy = 0.82, Confidence Probability = 0.22, Time of Classification = 0.1101 seconds
# Q-table:
# [[-0.01       -0.01786947 -0.01963187 -0.01927893  0.286957  ]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.29137356]
#  [-0.0379518  -0.01941232 -0.01       -0.01        0.28012365]
#  ...
#  [-0.0202368  -0.0107875  -0.0309835  -0.02097934  0.24976721]
#  [-0.01109451 -0.02163735 -0.02881544 -0.03003007  0.2423807 ]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.26667187]]
# Episode 37: Total Reward = 386.7873665833546, Accuracy = 0.82, Confidence Probability = 0.22, Time of Classification = 0.1206 seconds
# Q-table:
# [[-0.01       -0.01786947 -0.01963187 -0.01927893  0.29670979]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.30098094]
#  [-0.0379518  -0.01941232 -0.01       -0.01        0.29000477]
#  ...
#  [-0.0202368  -0.01970454 -0.0309835  -0.02097934  0.24976721]
#  [-0.01109451 -0.02163735 -0.02881544 -0.03003007  0.2511506 ]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.27519885]]
# Episode 38: Total Reward = 382.1151824833835, Accuracy = 0.82, Confidence Probability = 0.22, Time of Classification = 0.0786 seconds
# Q-table:
# [[-0.01       -0.01786947 -0.01963187 -0.01927893  0.30645152]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.31058117]
#  [-0.0379518  -0.01941232 -0.01       -0.01        0.29987452]
#  ...
#  [-0.0202368  -0.01970454 -0.0309835  -0.02097934  0.25874422]
#  [-0.01109451 -0.02163735 -0.02881544 -0.03003007  0.26033021]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.28413799]]
# Episode 39: Total Reward = 416.4730943611638, Accuracy = 0.83, Confidence Probability = 0.22, Time of Classification = 0.0676 seconds
# Q-table:
# [[-0.01       -0.02505254 -0.01963187 -0.01927893  0.30645152]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.32001724]
#  [-0.0379518  -0.01941232 -0.01       -0.01        0.30957591]
#  ...
#  [-0.0202368  -0.01970454 -0.0309835  -0.02097934  0.26782978]
#  [-0.01109451 -0.02163735 -0.02881544 -0.03003007  0.26960846]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.29317816]]
# Episode 40: Total Reward = 385.6480330201474, Accuracy = 0.83, Confidence Probability = 0.22, Time of Classification = 0.1018 seconds
# Q-table:
# [[-0.01       -0.02505254 -0.01963187 -0.01927893  0.31626716]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.32960325]
#  [-0.0379518  -0.01941232 -0.01       -0.01        0.3194231 ]
#  ...
#  [-0.0202368  -0.01970454 -0.0309835  -0.02097934  0.27655957]
#  [-0.01109451 -0.02163735 -0.02881544 -0.03003007  0.27853259]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.30186659]]
# Episode 41: Total Reward = 392.310001486457, Accuracy = 0.83, Confidence Probability = 0.22, Time of Classification = 0.1340 seconds
# Q-table:
# [[-0.01       -0.02505254 -0.01963187 -0.01927893  0.32607092]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.33918202]
#  [-0.0379518  -0.01941232 -0.01       -0.01        0.32910265]
#  ...
#  [-0.0202368  -0.01970454 -0.0309835  -0.02097934  0.28496035]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03003007  0.27853259]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.31022431]]
# Episode 42: Total Reward = 384.4470149453874, Accuracy = 0.83, Confidence Probability = 0.22, Time of Classification = 0.0888 seconds
# Q-table:
# [[-0.01       -0.02505254 -0.01963187 -0.01927893  0.33585714]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.34874642]
#  [-0.0379518  -0.01941232 -0.01       -0.01        0.33892082]
#  ...
#  [-0.0202368  -0.01970454 -0.0309835  -0.02097934  0.29372989]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03003007  0.28765163]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.31902643]]
# Episode 43: Total Reward = 374.3039719688091, Accuracy = 0.84, Confidence Probability = 0.23, Time of Classification = 0.1292 seconds
# Q-table:
# [[-0.01       -0.02505254 -0.01963187 -0.01927893  0.34563729]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.35830924]
#  [-0.0379518  -0.01941232 -0.01       -0.01        0.34873262]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02097934  0.29372989]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03003007  0.29635464]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.32741569]]
# Episode 44: Total Reward = 397.1897827724488, Accuracy = 0.84, Confidence Probability = 0.23, Time of Classification = 0.1009 seconds
# Q-table:
# [[-0.01       -0.02505254 -0.01963187 -0.01927893  0.3554057 ]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.36786474]
#  [-0.04428544 -0.01941232 -0.01       -0.01        0.34873262]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02097934  0.30245054]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03003007  0.3053286 ]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.33607904]]
# Episode 45: Total Reward = 389.82278357359223, Accuracy = 0.84, Confidence Probability = 0.23, Time of Classification = 0.0613 seconds
# Q-table:
# [[-0.01       -0.02505254 -0.01963187 -0.01927893  0.36516242]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.37732469]
#  [-0.04428544 -0.01941232 -0.01       -0.01        0.35856697]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02097934  0.31156131]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03003007  0.31468734]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.34513028]]
# Episode 46: Total Reward = 409.57907048446367, Accuracy = 0.84, Confidence Probability = 0.23, Time of Classification = 0.1102 seconds
# Q-table:
# [[-0.01       -0.02505254 -0.01963187 -0.01927893  0.37490672]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.38677855]
#  [-0.04428544 -0.01941232 -0.01       -0.01        0.36829381]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02097934  0.32017636]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03003007  0.32354512]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.35368362]]
# Episode 47: Total Reward = 394.50873562613594, Accuracy = 0.84, Confidence Probability = 0.23, Time of Classification = 0.1343 seconds
# Q-table:
# [[-0.01       -0.02505254 -0.01963187 -0.01927893  0.38463866]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.3962254 ]
#  [-0.04428544 -0.01941232 -0.01       -0.01        0.37815355]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02097934  0.32854342]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03003007  0.33214974]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.36198686]]
# Episode 48: Total Reward = 411.9542174427403, Accuracy = 0.85, Confidence Probability = 0.23, Time of Classification = 0.1571 seconds
# Q-table:
# [[-0.01       -0.02505254 -0.01963187 -0.01927893  0.3943583 ]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.40566653]
#  [-0.04428544 -0.01941232 -0.01       -0.01        0.38800038]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02097934  0.33667635]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03003007  0.34051514]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.37005389]]
# Episode 49: Total Reward = 396.1445681115781, Accuracy = 0.85, Confidence Probability = 0.23, Time of Classification = 0.1014 seconds
# Q-table:
# [[-0.01       -0.02505254 -0.01963187 -0.01927893  0.40405067]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.41508682]
#  [-0.04428544 -0.01941232 -0.01       -0.01        0.39781385]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02097934  0.34536044]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03003007  0.34942669]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.37867005]]
# Episode 50: Total Reward = 387.2365297686498, Accuracy = 0.85, Confidence Probability = 0.23, Time of Classification = 0.1291 seconds
# Q-table:
# [[-0.01       -0.02505254 -0.01963187 -0.01927893  0.41374595]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.42451628]
#  [-0.04428544 -0.01941232 -0.01       -0.01        0.40763494]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02891576  0.34536044]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03003007  0.3580494 ]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.38700033]]
# Episode 51: Total Reward = 376.36759083180453, Accuracy = 0.85, Confidence Probability = 0.23, Time of Classification = 0.1308 seconds
# Q-table:
# [[-0.01       -0.02505254 -0.01963187 -0.01927893  0.42342913]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.43393983]
#  [-0.04428544 -0.01941232 -0.01601614 -0.01        0.40763494]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02891576  0.35382157]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03003007  0.3666442 ]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.39530562]]
# Episode 52: Total Reward = 401.86458188492463, Accuracy = 0.85, Confidence Probability = 0.23, Time of Classification = 0.1153 seconds
# Q-table:
# [[-0.01       -0.02505254 -0.01963187 -0.01927893  0.4331003 ]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.44326915]
#  [-0.04428544 -0.01941232 -0.01601614 -0.01        0.417527  ]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02891576  0.36242994]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03003007  0.3753823 ]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.4037571 ]]
# Episode 53: Total Reward = 405.1400847759655, Accuracy = 0.85, Confidence Probability = 0.23, Time of Classification = 0.1105 seconds
# Q-table:
# [[-0.01       -0.02505254 -0.01963187 -0.01927893  0.44275872]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.4525942 ]
#  [-0.04428544 -0.01941232 -0.01601614 -0.01        0.4274046 ]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02891576  0.37108501]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03003007  0.38415738]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.41224843]]
# Episode 54: Total Reward = 399.5995404441031, Accuracy = 0.85, Confidence Probability = 0.23, Time of Classification = 0.0942 seconds
# Q-table:
# [[-0.01       -0.03073425 -0.01963187 -0.01927893  0.44275872]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.46190931]
#  [-0.04428544 -0.01941232 -0.01601614 -0.01        0.4372516 ]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02891576  0.37988977]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03003007  0.39308423]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.42089438]]
# Episode 55: Total Reward = 403.7251662207462, Accuracy = 0.86, Confidence Probability = 0.23, Time of Classification = 0.0891 seconds
# Q-table:
# [[-0.01       -0.03073425 -0.01963187 -0.01927893  0.45248832]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.47122548]
#  [-0.04428544 -0.01941232 -0.01601614 -0.01        0.44710049]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02891576  0.38873731]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03003007  0.40205011]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.42958216]]
# Episode 56: Total Reward = 414.96150460896206, Accuracy = 0.86, Confidence Probability = 0.23, Time of Classification = 0.0631 seconds
# Q-table:
# [[-0.01       -0.03618588 -0.01963187 -0.01927893  0.45248832]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.48053713]
#  [-0.04428544 -0.02491258 -0.01601614 -0.01        0.44710049]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02891576  0.39783757]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03003007  0.41126504]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.43852176]]
# Episode 57: Total Reward = 415.73464646549087, Accuracy = 0.86, Confidence Probability = 0.24, Time of Classification = 0.0850 seconds
# Q-table:
# [[-0.01       -0.03618588 -0.01963187 -0.01927893  0.46228827]
#  [-0.01933026 -0.01       -0.01015627 -0.0187216   0.48975566]
#  [-0.04428544 -0.02491258 -0.01601614 -0.01        0.45701924]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02891576  0.40671011]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03003007  0.42024861]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.44723277]]
# Episode 58: Total Reward = 395.17785775874364, Accuracy = 0.86, Confidence Probability = 0.24, Time of Classification = 0.1031 seconds
# Q-table:
# [[-0.01       -0.03618588 -0.01963187 -0.01927893  0.47207319]
#  [-0.01933026 -0.01578683 -0.01015627 -0.0187216   0.48975566]
#  [-0.04428544 -0.02491258 -0.01601614 -0.01        0.46692285]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02891576  0.41539464]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03003007  0.42904062]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.45575493]]
# Episode 59: Total Reward = 404.45513296615735, Accuracy = 0.86, Confidence Probability = 0.24, Time of Classification = 0.0635 seconds
# Q-table:
# [[-0.01       -0.03618588 -0.01963187 -0.01927893  0.48176025]
#  [-0.01933026 -0.01578683 -0.01015627 -0.0187216   0.49906041]
#  [-0.04428544 -0.02491258 -0.01601614 -0.01        0.47681141]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02891576  0.42446691]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03003007  0.43821686]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.46466403]]
# Episode 60: Total Reward = 418.69360302152637, Accuracy = 0.86, Confidence Probability = 0.24, Time of Classification = 0.0933 seconds
# Q-table:
# [[-0.01       -0.03618588 -0.01963187 -0.01927893  0.4914342 ]
#  [-0.01933026 -0.01578683 -0.01015627 -0.0187216   0.50836111]
#  [-0.04428544 -0.02491258 -0.01601614 -0.01        0.48668498]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02891576  0.43323319]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03003007  0.44708366]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.47326636]]
# Episode 61: Total Reward = 421.50868752030925, Accuracy = 0.86, Confidence Probability = 0.24, Time of Classification = 0.1106 seconds
# Q-table:
# [[-0.01       -0.03618588 -0.01963187 -0.01927893  0.5010951 ]
#  [-0.01933026 -0.01578683 -0.01015627 -0.0187216   0.51765767]
#  [-0.04428544 -0.02491258 -0.01601614 -0.01        0.49654363]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02891576  0.44197528]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03003007  0.45576667]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.48168755]]
# Episode 62: Total Reward = 414.95399422957314, Accuracy = 0.86, Confidence Probability = 0.24, Time of Classification = 0.0444 seconds
# Q-table:
# [[-0.01       -0.03618588 -0.01963187 -0.01927893  0.51074307]
#  [-0.01933026 -0.01578683 -0.01015627 -0.0187216   0.52694998]
#  [-0.04428544 -0.02491258 -0.01601614 -0.01        0.50638743]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02891576  0.4512138 ]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03003007  0.46510057]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.49076223]]
# Episode 63: Total Reward = 407.05479961527215, Accuracy = 0.87, Confidence Probability = 0.24, Time of Classification = 0.0957 seconds
# Q-table:
# [[-0.01       -0.03618588 -0.01963187 -0.01927893  0.52037819]
#  [-0.01933026 -0.01578683 -0.01015627 -0.0187216   0.53623797]
#  [-0.04428544 -0.02491258 -0.01601614 -0.01        0.51621645]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02891576  0.45993025]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03003007  0.4739091 ]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.49931415]]
# Episode 64: Total Reward = 380.23211357954705, Accuracy = 0.87, Confidence Probability = 0.24, Time of Classification = 0.1226 seconds
# Q-table:
# [[-0.01       -0.03618588 -0.01963187 -0.01927893  0.52984427]
#  [-0.01933026 -0.01578683 -0.01015627 -0.0187216   0.54536525]
#  [-0.04428544 -0.02491258 -0.01601614 -0.01        0.52587447]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02891576  0.46837005]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03646203  0.4739091 ]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.50758876]]
# Episode 65: Total Reward = 406.09341547816746, Accuracy = 0.87, Confidence Probability = 0.24, Time of Classification = 0.1053 seconds
# Q-table:
# [[-0.01       -0.03618588 -0.01963187 -0.01927893  0.53945411]
#  [-0.01933026 -0.01578683 -0.01015627 -0.0187216   0.55464447]
#  [-0.04428544 -0.02491258 -0.01601614 -0.01        0.53567428]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02891576  0.47689873]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03646203  0.48268551]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.51602837]]
# Episode 66: Total Reward = 400.13171446981363, Accuracy = 0.87, Confidence Probability = 0.24, Time of Classification = 0.1368 seconds
# Q-table:
# [[-0.01       -0.03618588 -0.01963187 -0.01927893  0.54905137]
#  [-0.01933026 -0.01578683 -0.01015627 -0.0187216   0.5639191 ]
#  [-0.04428544 -0.02491258 -0.01601614 -0.01        0.54545875]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02891576  0.48510603]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03646203  0.49113503]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.52414446]]
# Episode 67: Total Reward = 413.6635015588757, Accuracy = 0.87, Confidence Probability = 0.24, Time of Classification = 0.0983 seconds
# Q-table:
# [[-0.01       -0.03618588 -0.01963187 -0.01927893  0.55859377]
#  [-0.01933026 -0.01578683 -0.01015627 -0.0187216   0.573141  ]
#  [-0.04428544 -0.02491258 -0.01601614 -0.01472423  0.54545875]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02891576  0.49369217]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03646203  0.49995797]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.5326373 ]]
# Episode 68: Total Reward = 419.8816186055349, Accuracy = 0.87, Confidence Probability = 0.24, Time of Classification = 0.1061 seconds
# Q-table:
# [[-0.01       -0.03618588 -0.01963187 -0.01927893  0.5681661 ]
#  [-0.01933026 -0.01578683 -0.01015627 -0.0187216   0.58230825]
#  [-0.04428544 -0.02491258 -0.01601614 -0.01472423  0.55529954]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02891576  0.50219361]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03646203  0.50869086]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.5410434 ]]
# Episode 69: Total Reward = 412.61467426192405, Accuracy = 0.87, Confidence Probability = 0.24, Time of Classification = 0.1106 seconds
# Q-table:
# [[-0.01       -0.03618588 -0.01963187 -0.01927893  0.57770964]
#  [-0.01933026 -0.01578683 -0.01015627 -0.0187216   0.59146729]
#  [-0.04428544 -0.02491258 -0.01601614 -0.01472423  0.56511917]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02891576  0.51065754]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03646203  0.51736735]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.54939637]]
# Episode 70: Total Reward = 409.34713602065403, Accuracy = 0.87, Confidence Probability = 0.25, Time of Classification = 0.1024 seconds
# Q-table:
# [[-0.01       -0.03618588 -0.01963187 -0.01927893  0.58725575]
#  [-0.01933026 -0.01578683 -0.01015627 -0.0187216   0.60063869]
#  [-0.04428544 -0.02491258 -0.01601614 -0.01472423  0.5749384 ]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02891576  0.51918279]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03646203  0.52611377]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02094162  0.5578225 ]]
# Episode 71: Total Reward = 400.508395231091, Accuracy = 0.87, Confidence Probability = 0.25, Time of Classification = 0.0709 seconds
# Q-table:
# [[-0.01       -0.03618588 -0.01963187 -0.01927893  0.59678894]
#  [-0.01933026 -0.01578683 -0.01015627 -0.0187216   0.60980675]
#  [-0.04428544 -0.02491258 -0.02030326 -0.01472423  0.5749384 ]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02891576  0.52801726]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03646203  0.5351643 ]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02642054  0.5578225 ]]
# Episode 72: Total Reward = 422.39594468111125, Accuracy = 0.87, Confidence Probability = 0.25, Time of Classification = 0.0806 seconds
# Q-table:
# [[-0.01       -0.03618588 -0.01963187 -0.01927893  0.60630931]
#  [-0.01933026 -0.01578683 -0.01015627 -0.0187216   0.61888313]
#  [-0.04428544 -0.02491258 -0.02030326 -0.01472423  0.58482396]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.02891576  0.53674778]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03646203  0.54402728]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02642054  0.56645889]]
# Episode 73: Total Reward = 407.45713778530785, Accuracy = 0.87, Confidence Probability = 0.25, Time of Classification = 0.0944 seconds
# Q-table:
# [[-0.01       -0.03618588 -0.01963187 -0.01927893  0.61580429]
#  [-0.01933026 -0.02038315 -0.01015627 -0.0187216   0.61888313]
#  [-0.04428544 -0.02896397 -0.02030326 -0.01472423  0.58482396]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.03467428  0.53674778]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03646203  0.55274121]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02642054  0.57494851]]
# Episode 74: Total Reward = 387.46171196670923, Accuracy = 0.87, Confidence Probability = 0.25, Time of Classification = 0.1338 seconds
# Q-table:
# [[-0.01       -0.03618588 -0.01963187 -0.01927893  0.62521619]
#  [-0.01933026 -0.02038315 -0.01015627 -0.0187216   0.62795771]
#  [-0.04428544 -0.02896397 -0.02030326 -0.01472423  0.59477472]
#  ...
#  [-0.02873728 -0.01970454 -0.0309835  -0.03467428  0.54501683]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03646203  0.56105019]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02642054  0.58303541]]
# Episode 75: Total Reward = 394.03695171524254, Accuracy = 0.87, Confidence Probability = 0.25, Time of Classification = 0.1081 seconds
# Q-table:
# [[-0.01       -0.03618588 -0.01963187 -0.01927893  0.63461565]
#  [-0.01933026 -0.02038315 -0.01015627 -0.0187216   0.63703111]
#  [-0.04428544 -0.02896397 -0.02030326 -0.01472423  0.60470797]
#  ...
#  [-0.02873728 -0.01970454 -0.03670495 -0.03467428  0.54501683]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03646203  0.56960628]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02642054  0.59137165]]
# Episode 76: Total Reward = 411.0601667815077, Accuracy = 0.88, Confidence Probability = 0.25, Time of Classification = 0.1157 seconds
# Q-table:
# [[-0.01       -0.03618588 -0.01963187 -0.01927893  0.64400277]
#  [-0.01933026 -0.02038315 -0.01015627 -0.0187216   0.64610317]
#  [-0.04428544 -0.02896397 -0.02030326 -0.01472423  0.6146238 ]
#  ...
#  [-0.02873728 -0.01970454 -0.03670495 -0.03467428  0.55353596]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03646203  0.5780754 ]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02642054  0.59962312]]
# Episode 77: Total Reward = 417.0372198273861, Accuracy = 0.88, Confidence Probability = 0.25, Time of Classification = 0.0519 seconds
# Q-table:
# [[-0.01       -0.03618588 -0.01963187 -0.01927893  0.65337768]
#  [-0.01933026 -0.02038315 -0.01015627 -0.0187216   0.65517375]
#  [-0.04428544 -0.02896397 -0.02030326 -0.01472423  0.62452232]
#  ...
#  [-0.02873728 -0.01970454 -0.03670495 -0.03467428  0.56268466]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03646203  0.58717264]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02642054  0.60850487]]
# Episode 78: Total Reward = 397.5628403866597, Accuracy = 0.88, Confidence Probability = 0.25, Time of Classification = 0.1246 seconds
# Q-table:
# [[-0.01       -0.03618588 -0.01963187 -0.01927893  0.66274046]
#  [-0.01933026 -0.02038315 -0.01015627 -0.0187216   0.66424272]
#  [-0.04428544 -0.02896397 -0.02030326 -0.01472423  0.63440363]
#  ...
#  [-0.02873728 -0.01970454 -0.03670495 -0.03467428  0.57109625]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03646203  0.59553134]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02642054  0.61665026]]
# Episode 79: Total Reward = 421.13145806729057, Accuracy = 0.88, Confidence Probability = 0.25, Time of Classification = 0.0662 seconds
# Q-table:
# [[-0.01       -0.03618588 -0.01963187 -0.01927893  0.67209124]
#  [-0.01933026 -0.02038315 -0.01015627 -0.0187216   0.67330992]
#  [-0.04428544 -0.02896397 -0.02030326 -0.01472423  0.64426781]
#  ...
#  [-0.02873728 -0.01970454 -0.03670495 -0.03467428  0.5800832 ]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03646203  0.60446401]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02642054  0.62537174]]
# Episode 80: Total Reward = 410.9062265826159, Accuracy = 0.88, Confidence Probability = 0.25, Time of Classification = 0.0913 seconds
# Q-table:
# [[-0.01       -0.03618588 -0.01963187 -0.01927893  0.68143012]
#  [-0.01933026 -0.02038315 -0.01015627 -0.0187216   0.68237523]
#  [-0.04428544 -0.02896397 -0.02030326 -0.01472423  0.65411495]
#  ...
#  [-0.02873728 -0.01970454 -0.03670495 -0.03467428  0.5888301 ]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03646203  0.61313457]
#  [-0.02127355 -0.0107875  -0.01068331 -0.02642054  0.63383322]]
# Episode 81: Total Reward = 422.60235836654635, Accuracy = 0.88, Confidence Probability = 0.25, Time of Classification = 0.0736 seconds
# Q-table:
# [[-0.01375862 -0.03618588 -0.01963187 -0.01927893  0.68143012]
#  [-0.01933026 -0.02038315 -0.01015627 -0.0187216   0.69143851]
#  [-0.04428544 -0.02896397 -0.02030326 -0.01472423  0.66394514]
#  ...
#  [-0.02873728 -0.01970454 -0.03670495 -0.03467428  0.59772418]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03646203  0.6219719 ]
#  [-0.02127355 -0.01571096 -0.01068331 -0.02642054  0.63383322]]
# Episode 82: Total Reward = 428.7577810275716, Accuracy = 0.88, Confidence Probability = 0.25, Time of Classification = 0.1022 seconds
# Q-table:
# [[-0.01375862 -0.03618588 -0.01963187 -0.01927893  0.69083876]
#  [-0.01933026 -0.02038315 -0.01015627 -0.0187216   0.70049964]
#  [-0.04428544 -0.02896397 -0.02030326 -0.01472423  0.67375847]
#  ...
#  [-0.02873728 -0.01970454 -0.03670495 -0.03467428  0.60632279]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03646203  0.63043479]
#  [-0.02127355 -0.01571096 -0.01068331 -0.02642054  0.6421775 ]]
# Episode 83: Total Reward = 423.3159518530151, Accuracy = 0.88, Confidence Probability = 0.25, Time of Classification = 0.0448 seconds
# Q-table:
# [[-0.01375862 -0.03618588 -0.01963187 -0.01927893  0.70023487]
#  [-0.01933026 -0.02038315 -0.01015627 -0.0187216   0.70955847]
#  [-0.04428544 -0.02896397 -0.02030326 -0.01472423  0.68355501]
#  ...
#  [-0.02873728 -0.01970454 -0.03670495 -0.03467428  0.61548567]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03646203  0.63946223]
#  [-0.02127355 -0.01571096 -0.01068331 -0.02642054  0.65108752]]
# Episode 84: Total Reward = 410.099999563437, Accuracy = 0.88, Confidence Probability = 0.26, Time of Classification = 0.1124 seconds
# Q-table:
# [[-0.01375862 -0.03618588 -0.01963187 -0.01927893  0.70961855]
#  [-0.01933026 -0.02038315 -0.01015627 -0.0187216   0.71861488]
#  [-0.04428544 -0.02896397 -0.02030326 -0.01472423  0.69333484]
#  ...
#  [-0.02873728 -0.01970454 -0.03670495 -0.03467428  0.62396733]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03646203  0.64780349]
#  [-0.02127355 -0.01571096 -0.01068331 -0.02642054  0.65931252]]
# Episode 85: Total Reward = 400.9703755963264, Accuracy = 0.88, Confidence Probability = 0.26, Time of Classification = 0.0617 seconds
# Q-table:
# [[-0.01375862 -0.03618588 -0.01963187 -0.01927893  0.7189899 ]
#  [-0.01933026 -0.02038315 -0.01015627 -0.0187216   0.72765505]
#  [-0.04716532 -0.02896397 -0.02030326 -0.01472423  0.69333484]
#  ...
#  [-0.02873728 -0.01970454 -0.03670495 -0.03467428  0.63294055]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03646203  0.65664193]
#  [-0.02127355 -0.01571096 -0.01068331 -0.02642054  0.66803587]]
# Episode 86: Total Reward = 377.7686913919521, Accuracy = 0.88, Confidence Probability = 0.26, Time of Classification = 0.1331 seconds
# Q-table:
# [[-0.01375862 -0.03618588 -0.01963187 -0.01927893  0.7283489 ]
#  [-0.01933026 -0.02038315 -0.01015627 -0.0187216   0.73661852]
#  [-0.0499162  -0.02896397 -0.02030326 -0.01472423  0.69333484]
#  ...
#  [-0.02873728 -0.01970454 -0.03670495 -0.03467428  0.64118953]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03646203  0.66475644]
#  [-0.02127355 -0.01571096 -0.01589554 -0.02642054  0.66803587]]
# Episode 87: Total Reward = 419.8376510465679, Accuracy = 0.88, Confidence Probability = 0.26, Time of Classification = 0.1506 seconds
# Q-table:
# [[-0.01375862 -0.03618588 -0.01963187 -0.01927893  0.73769497]
#  [-0.01933026 -0.02038315 -0.01015627 -0.0187216   0.74549234]
#  [-0.0499162  -0.02896397 -0.02030326 -0.01472423  0.70325995]
#  ...
#  [-0.02873728 -0.01970454 -0.03670495 -0.03467428  0.64925454]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03646203  0.67261529]
#  [-0.02127355 -0.01571096 -0.01589554 -0.02642054  0.67586193]]
# Episode 88: Total Reward = 400.3203736699859, Accuracy = 0.88, Confidence Probability = 0.26, Time of Classification = 0.1003 seconds
# Q-table:
# [[-0.01375862 -0.03618588 -0.01963187 -0.01927893  0.74702746]
#  [-0.01933026 -0.02038315 -0.01015627 -0.0187216   0.75436676]
#  [-0.0499162  -0.02896397 -0.02030326 -0.01472423  0.71316673]
#  ...
#  [-0.02873728 -0.01970454 -0.03670495 -0.03467428  0.6578121 ]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03646203  0.68096847]
#  [-0.02127355 -0.01571096 -0.01589554 -0.02642054  0.68418265]]
# Episode 89: Total Reward = 417.7267862917546, Accuracy = 0.88, Confidence Probability = 0.26, Time of Classification = 0.1110 seconds
# Q-table:
# [[-0.01375862 -0.03618588 -0.01963187 -0.01927893  0.75633445]
#  [-0.01933026 -0.02038315 -0.01015627 -0.0187216   0.76322956]
#  [-0.0499162  -0.02896397 -0.02030326 -0.01472423  0.72304324]
#  ...
#  [-0.02873728 -0.01970454 -0.03670495 -0.03467428  0.66625249]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03646203  0.68920622]
#  [-0.02127355 -0.01571096 -0.01589554 -0.02642054  0.69238825]]
# Episode 90: Total Reward = 428.78349362276714, Accuracy = 0.88, Confidence Probability = 0.26, Time of Classification = 0.0791 seconds
# Q-table:
# [[-0.01375862 -0.03618588 -0.01963187 -0.01927893  0.76564017]
#  [-0.01933026 -0.02038315 -0.01015627 -0.0187216   0.77210465]
#  [-0.0499162  -0.02896397 -0.02030326 -0.01472423  0.73291348]
#  ...
#  [-0.02873728 -0.01970454 -0.03670495 -0.03467428  0.67500172]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03646203  0.69775456]
#  [-0.02127355 -0.01571096 -0.01589554 -0.02642054  0.70090477]]
# Episode 91: Total Reward = 414.59677478355695, Accuracy = 0.88, Confidence Probability = 0.26, Time of Classification = 0.0697 seconds
# Q-table:
# [[-0.01375862 -0.03618588 -0.01963187 -0.01927893  0.77493271]
#  [-0.01933026 -0.02038315 -0.01015627 -0.0187216   0.78097983]
#  [-0.0499162  -0.02896397 -0.02030326 -0.01472423  0.74276569]
#  ...
#  [-0.02873728 -0.01970454 -0.03670495 -0.03467428  0.68383417]
#  [-0.01109451 -0.02163735 -0.0371509  -0.03646203  0.70638783]
#  [-0.02127355 -0.01571096 -0.01589554 -0.02642054  0.70950654]]
# ...
#  [-0.02505928 -0.01914405 -0.0247561  -0.02219907  0.61264743]
#  [-0.02177418 -0.02939202 -0.02039496 -0.01890673  0.61484193]
#  ...
#  [-0.03188634 -0.03346221 -0.01719725 -0.01116613  0.54973085]
#  [-0.03126318 -0.01124129 -0.02878104 -0.02641762  0.56107192]
#  [-0.0181624  -0.01771143 -0.01108972 -0.01116613  0.59416436]]
# Episode 75: Total Reward = 405.49246317865925, Accuracy = 0.87, Confidence Probability = 0.25, Time of Classification = 0.1793 seconds
# Q-table:
# [[-0.04050073 -0.03109621 -0.05002412 -0.01830503  0.56909391]
#  [-0.02505928 -0.01914405 -0.0247561  -0.02219907  0.62205453]
#  [-0.02177418 -0.02939202 -0.02039496 -0.01890673  0.62439793]
#  ...
#  [-0.03188634 -0.03346221 -0.01719725 -0.01116613  0.55750111]
#  [-0.03126318 -0.01124129 -0.02878104 -0.02641762  0.56901543]
#  [-0.0181624  -0.01771143 -0.01108972 -0.01116613  0.60177694]]
# Episode 76: Total Reward = 421.3289959492286, Accuracy = 0.87, Confidence Probability = 0.25, Time of Classification = 0.1472 seconds
# Q-table:
# [[-0.04050073 -0.03109621 -0.05002412 -0.01830503  0.57900146]
#  [-0.02505928 -0.01914405 -0.0247561  -0.02219907  0.63145357]
#  [-0.02177418 -0.02939202 -0.02039496 -0.01890673  0.63394226]
#  ...
#  [-0.03188634 -0.03947854 -0.01719725 -0.01116613  0.55750111]
#  [-0.03126318 -0.01124129 -0.02878104 -0.02641762  0.57726917]
#  [-0.0181624  -0.01771143 -0.01108972 -0.01116613  0.60970306]]
# Episode 77: Total Reward = 435.8139966491746, Accuracy = 0.87, Confidence Probability = 0.25, Time of Classification = 0.1124 seconds
# Q-table:
# [[-0.04050073 -0.03109621 -0.05002412 -0.01830503  0.58889453]
#  [-0.02505928 -0.02324713 -0.0247561  -0.02219907  0.63145357]
#  [-0.02177418 -0.02939202 -0.02039496 -0.01890673  0.64339115]
#  ...
#  [-0.03188634 -0.03947854 -0.01719725 -0.01116613  0.56599733]
#  [-0.03126318 -0.01124129 -0.02878104 -0.02641762  0.58585961]
#  [-0.0181624  -0.01771143 -0.01108972 -0.01116613  0.61796916]]
# Episode 78: Total Reward = 404.2401614392663, Accuracy = 0.87, Confidence Probability = 0.25, Time of Classification = 0.1573 seconds
# Q-table:
# [[-0.04050073 -0.03109621 -0.05002412 -0.01830503  0.59868867]
#  [-0.02505928 -0.02324713 -0.0247561  -0.02219907  0.64092955]
#  [-0.02177418 -0.02939202 -0.02039496 -0.01890673  0.65267374]
#  ...
#  [-0.03188634 -0.03947854 -0.01719725 -0.01116613  0.574037  ]
#  [-0.03126318 -0.01124129 -0.02878104 -0.03216481  0.58585961]
#  [-0.0181624  -0.01771143 -0.01108972 -0.01116613  0.62577811]]
# Episode 79: Total Reward = 413.24185603033465, Accuracy = 0.87, Confidence Probability = 0.25, Time of Classification = 0.0674 seconds
# Q-table:
# [[-0.04050073 -0.03109621 -0.05002412 -0.01830503  0.60847015]
#  [-0.02505928 -0.02324713 -0.0247561  -0.02219907  0.65039432]
#  [-0.02177418 -0.02939202 -0.02039496 -0.01890673  0.66210298]
#  ...
#  [-0.03188634 -0.03947854 -0.01719725 -0.01116613  0.58289503]
#  [-0.03126318 -0.01124129 -0.02878104 -0.03216481  0.59495868]
#  [-0.0181624  -0.01771143 -0.01108972 -0.01116613  0.63447799]]
# Episode 80: Total Reward = 429.2955244022484, Accuracy = 0.87, Confidence Probability = 0.25, Time of Classification = 0.1338 seconds
# Q-table:
# [[-0.04050073 -0.03109621 -0.05002412 -0.01830503  0.61823899]
#  [-0.02505928 -0.02324713 -0.0247561  -0.02219907  0.6598493 ]
#  [-0.02177418 -0.02939202 -0.02039496 -0.01890673  0.67152234]
#  ...
#  [-0.03188634 -0.03947854 -0.01719725 -0.01116613  0.59108244]
#  [-0.03126318 -0.01124129 -0.02878104 -0.03216481  0.60338112]
#  [-0.0181624  -0.01771143 -0.01108972 -0.01116613  0.64250524]]
# Episode 81: Total Reward = 427.2843961020031, Accuracy = 0.87, Confidence Probability = 0.25, Time of Classification = 0.0902 seconds
# Q-table:
# [[-0.04050073 -0.03109621 -0.05002412 -0.01830503  0.62799525]
#  [-0.02505928 -0.02324713 -0.0247561  -0.02219907  0.66929451]
#  [-0.02177418 -0.02939202 -0.02039496 -0.01890673  0.68093185]
#  ...
#  [-0.03188634 -0.03947854 -0.01719725 -0.01116613  0.59969983]
#  [-0.03126318 -0.01124129 -0.02878104 -0.03216481  0.61222765]
#  [-0.0181624  -0.01771143 -0.01108972 -0.01116613  0.65096052]]
# Episode 82: Total Reward = 423.70357826866876, Accuracy = 0.87, Confidence Probability = 0.25, Time of Classification = 0.0949 seconds
# Q-table:
# [[-0.04050073 -0.03109621 -0.05002412 -0.02209833  0.62799525]
#  [-0.02505928 -0.02324713 -0.0247561  -0.02219907  0.67872995]
#  [-0.02177418 -0.02939202 -0.02039496 -0.01890673  0.6903315 ]
#  ...
#  [-0.03188634 -0.03947854 -0.01719725 -0.01116613  0.60826391]
#  [-0.03126318 -0.01124129 -0.02878104 -0.03216481  0.62101505]
#  [-0.0181624  -0.01771143 -0.01108972 -0.01116613  0.65936059]]
# Episode 83: Total Reward = 440.1525752421701, Accuracy = 0.87, Confidence Probability = 0.25, Time of Classification = 0.1170 seconds
# Q-table:
# [[-0.04050073 -0.03109621 -0.05002412 -0.02209833  0.63782387]
#  [-0.02505928 -0.02324713 -0.0247561  -0.02219907  0.68815564]
#  [-0.02177418 -0.02939202 -0.02039496 -0.01890673  0.69972132]
#  ...
#  [-0.03188634 -0.03947854 -0.01719725 -0.01116613  0.61660068]
#  [-0.03126318 -0.01124129 -0.02878104 -0.03216481  0.62956942]
#  [-0.0181624  -0.01771143 -0.01108972 -0.01116613  0.66753151]]
# Episode 84: Total Reward = 408.01698765923294, Accuracy = 0.87, Confidence Probability = 0.25, Time of Classification = 0.0884 seconds
# Q-table:
# [[-0.04050073 -0.03109621 -0.05002412 -0.02209833  0.64763903]
#  [-0.02505928 -0.02324713 -0.0247561  -0.02219907  0.69757157]
#  [-0.02177418 -0.02939202 -0.02039496 -0.01890673  0.70910055]
#  ...
#  [-0.03188634 -0.03947854 -0.01719725 -0.01627186  0.61660068]
#  [-0.03126318 -0.01124129 -0.02878104 -0.03216481  0.638398  ]
#  [-0.0181624  -0.01771143 -0.01108972 -0.01116613  0.67598047]]
# Episode 85: Total Reward = 412.62306356775326, Accuracy = 0.87, Confidence Probability = 0.26, Time of Classification = 0.1135 seconds
# Q-table:
# [[-0.04050073 -0.03109621 -0.05002412 -0.02209833  0.65744078]
#  [-0.02842679 -0.02324713 -0.0247561  -0.02219907  0.69757157]
#  [-0.02177418 -0.02939202 -0.02039496 -0.01890673  0.71838599]
#  ...
#  [-0.03188634 -0.03947854 -0.01719725 -0.01627186  0.62520178]
#  [-0.03126318 -0.01124129 -0.02878104 -0.03216481  0.64696311]
#  [-0.0181624  -0.01771143 -0.01108972 -0.01116613  0.68416976]]
# Episode 86: Total Reward = 456.67823221798665, Accuracy = 0.88, Confidence Probability = 0.26, Time of Classification = 0.1095 seconds
# Q-table:
# [[-0.04050073 -0.03109621 -0.05002412 -0.02209833  0.66714452]
#  [-0.02842679 -0.02324713 -0.0247561  -0.02219907  0.70706133]
#  [-0.02177418 -0.02939202 -0.02039496 -0.01890673  0.72766258]
#  ...
#  [-0.03188634 -0.03947854 -0.01719725 -0.01627186  0.63367783]
#  [-0.03126318 -0.01124129 -0.02878104 -0.03216481  0.65555642]
#  [-0.0181624  -0.01771143 -0.01108972 -0.01116613  0.69239099]]
# Episode 87: Total Reward = 418.00198679269107, Accuracy = 0.88, Confidence Probability = 0.26, Time of Classification = 0.1347 seconds
# Q-table:
# [[-0.04050073 -0.03109621 -0.05002412 -0.02209833  0.67683662]
#  [-0.02842679 -0.02324713 -0.0247561  -0.02219907  0.71653968]
#  [-0.02177418 -0.02939202 -0.02039496 -0.01890673  0.73693032]
#  ...
#  [-0.03188634 -0.03947854 -0.01719725 -0.01627186  0.64189414]
#  [-0.03126318 -0.01124129 -0.02878104 -0.03216481  0.66388545]
#  [-0.0181624  -0.01771143 -0.01108972 -0.01116613  0.70035168]]
# Episode 88: Total Reward = 397.60315311860705, Accuracy = 0.88, Confidence Probability = 0.26, Time of Classification = 0.1884 seconds
# Q-table:
# [[-0.04050073 -0.03109621 -0.05002412 -0.02209833  0.68651712]
#  [-0.02842679 -0.02324713 -0.0247561  -0.02219907  0.72600666]
#  [-0.02177418 -0.02939202 -0.02039496 -0.01890673  0.74618922]
#  ...
#  [-0.03188634 -0.03947854 -0.01719725 -0.01627186  0.64956659]
#  [-0.03126318 -0.01124129 -0.02878104 -0.03216481  0.67166618]
#  [-0.0181624  -0.01771143 -0.01108972 -0.01116613  0.70776775]]
# Episode 89: Total Reward = 432.0654325785117, Accuracy = 0.88, Confidence Probability = 0.26, Time of Classification = 0.1761 seconds
# Q-table:
# [[-0.04050073 -0.03109621 -0.05002412 -0.02209833  0.696186  ]
#  [-0.02842679 -0.02324713 -0.0247561  -0.02219907  0.73546229]
#  [-0.02177418 -0.02939202 -0.02039496 -0.01890673  0.75543927]
#  ...
#  [-0.03188634 -0.03947854 -0.01719725 -0.01627186  0.65735498]
#  [-0.03126318 -0.01124129 -0.02878104 -0.03216481  0.67955849]
#  [-0.0181624  -0.01771143 -0.01108972 -0.01116613  0.71529904]]
# Episode 90: Total Reward = 453.66078822272857, Accuracy = 0.88, Confidence Probability = 0.26, Time of Classification = 0.0847 seconds
# Q-table:
# [[-0.04050073 -0.03109621 -0.05002412 -0.02209833  0.70584331]
#  [-0.02842679 -0.02324713 -0.0247561  -0.02219907  0.74490662]
#  [-0.02177418 -0.02939202 -0.02039496 -0.01890673  0.7646805 ]
#  ...
#  [-0.03188634 -0.03947854 -0.01719725 -0.01627186  0.66604997]
#  [-0.03126318 -0.01124129 -0.02878104 -0.03216481  0.68835311]
#  [-0.0181624  -0.01771143 -0.01108972 -0.01116613  0.72373626]]
# Episode 91: Total Reward = 424.1771572487589, Accuracy = 0.88, Confidence Probability = 0.26, Time of Classification = 0.1245 seconds
# Q-table:
# [[-0.04050073 -0.03109621 -0.05002412 -0.02209833  0.71548903]
#  [-0.02842679 -0.02324713 -0.0247561  -0.02219907  0.75433968]
#  [-0.02177418 -0.02939202 -0.02039496 -0.01890673  0.7739129 ]
#  ...
#  [-0.03188634 -0.03947854 -0.01719725 -0.01627186  0.67434012]
#  [-0.03126318 -0.01124129 -0.03322413 -0.03216481  0.68835311]
#  [-0.0181624  -0.01771143 -0.01108972 -0.01116613  0.73176799]]
# Episode 92: Total Reward = 427.6781092601364, Accuracy = 0.88, Confidence Probability = 0.26, Time of Classification = 0.1191 seconds
# Q-table:
# [[-0.04050073 -0.03109621 -0.05002412 -0.02209833  0.7251232 ]
#  [-0.02842679 -0.02324713 -0.0247561  -0.02516892  0.75433968]
#  [-0.02177418 -0.02939202 -0.02338536 -0.01890673  0.7739129 ]
#  ...
#  [-0.03188634 -0.03947854 -0.01719725 -0.01627186  0.68260059]
#  [-0.03126318 -0.01124129 -0.03322413 -0.03216481  0.69686418]
#  [-0.0181624  -0.01771143 -0.01558422 -0.01116613  0.73176799]]
# Episode 93: Total Reward = 430.41342738983144, Accuracy = 0.88, Confidence Probability = 0.26, Time of Classification = 0.1254 seconds
# Q-table:
# [[-0.04050073 -0.03109621 -0.05002412 -0.02209833  0.73466102]
#  [-0.02842679 -0.02324713 -0.0247561  -0.02516892  0.7637615 ]
#  [-0.02177418 -0.02939202 -0.02338536 -0.01890673  0.78321849]
#  ...
#  [-0.03188634 -0.03947854 -0.01719725 -0.01627186  0.69079208]
#  [-0.03126318 -0.01124129 -0.03322413 -0.03216481  0.70522716]
#  [-0.0181624  -0.01771143 -0.01558422 -0.01116613  0.73978194]]
# Episode 94: Total Reward = 449.6974524562753, Accuracy = 0.88, Confidence Probability = 0.26, Time of Classification = 0.1003 seconds
# Q-table:
# [[-0.04050073 -0.03109621 -0.05002412 -0.02209833  0.74418827]
#  [-0.02842679 -0.02324713 -0.0247561  -0.02516892  0.77317285]
#  [-0.02177418 -0.02939202 -0.02338536 -0.02158961  0.78321849]
#  ...
#  [-0.03188634 -0.03947854 -0.01719725 -0.01627186  0.69922839]
#  [-0.03126318 -0.01124129 -0.03322413 -0.03216481  0.71383012]
#  [-0.0181624  -0.01771143 -0.01558422 -0.01116613  0.74803934]]
# Episode 95: Total Reward = 454.91699868453253, Accuracy = 0.88, Confidence Probability = 0.26, Time of Classification = 0.1175 seconds
# Q-table:
# [[-0.04050073 -0.03109621 -0.05002412 -0.02209833  0.75370494]
#  [-0.02842679 -0.02596569 -0.0247561  -0.02516892  0.77317285]
#  [-0.02177418 -0.02939202 -0.02338536 -0.02158961  0.7925976 ]
#  ...
#  [-0.03188634 -0.03947854 -0.01719725 -0.01627186  0.70748605]
#  [-0.03126318 -0.01124129 -0.03322413 -0.03216481  0.72224965]
#  [-0.0181624  -0.01771143 -0.01558422 -0.01116613  0.75611678]]
# Episode 96: Total Reward = 443.8114617319569, Accuracy = 0.88, Confidence Probability = 0.26, Time of Classification = 0.0685 seconds
# Q-table:
# [[-0.04050073 -0.03109621 -0.05002412 -0.02209833  0.76312645]
#  [-0.02842679 -0.02857265 -0.0247561  -0.02516892  0.77317285]
#  [-0.02177418 -0.02939202 -0.02338536 -0.02158961  0.80196607]
#  ...
#  [-0.03188634 -0.03947854 -0.01719725 -0.01627186  0.71622626]
#  [-0.03126318 -0.01124129 -0.03322413 -0.03216481  0.73114703]
#  [-0.0181624  -0.01771143 -0.01558422 -0.01116613  0.76467549]]
# Episode 97: Total Reward = 424.43227990007523, Accuracy = 0.88, Confidence Probability = 0.26, Time of Classification = 0.0967 seconds
# Q-table:
# [[-0.04050073 -0.03109621 -0.05002412 -0.02209833  0.77245374]
#  [-0.02842679 -0.02857265 -0.02729085 -0.02516892  0.77317285]
#  [-0.02177418 -0.02939202 -0.02338536 -0.0239962   0.80196607]
#  ...
#  [-0.03188634 -0.03947854 -0.01719725 -0.01627186  0.72467753]
#  [-0.03126318 -0.01124129 -0.03322413 -0.03216481  0.73975084]
#  [-0.0181624  -0.01771143 -0.01558422 -0.01116613  0.77294402]]
# Episode 98: Total Reward = 432.14571775562615, Accuracy = 0.88, Confidence Probability = 0.27, Time of Classification = 0.1354 seconds
# Q-table:
# [[-0.04050073 -0.03109621 -0.05002412 -0.02209833  0.78168776]
#  [-0.02842679 -0.03106923 -0.02729085 -0.02516892  0.77317285]
#  [-0.02177418 -0.02939202 -0.02338536 -0.0239962   0.8114069 ]
#  ...
#  [-0.03188634 -0.03947854 -0.01719725 -0.01627186  0.7327349 ]
#  [-0.03126318 -0.01124129 -0.03322413 -0.03216481  0.74795621]
#  [-0.0181624  -0.01771143 -0.01558422 -0.01116613  0.78081746]]
# Episode 99: Total Reward = 430.395771329559, Accuracy = 0.88, Confidence Probability = 0.27, Time of Classification = 0.1416 seconds
# Q-table:
# [[-0.04050073 -0.03109621 -0.05002412 -0.02209833  0.79082943]
#  [-0.02842679 -0.03106923 -0.02729085 -0.02516892  0.78274379]
#  [-0.0240138  -0.02939202 -0.02338536 -0.0239962   0.8114069 ]
#  ...
#  [-0.03188634 -0.03947854 -0.01719725 -0.01627186  0.74072348]
#  [-0.03126318 -0.01124129 -0.03322413 -0.03216481  0.75608833]
#  [-0.0181624  -0.01771143 -0.01558422 -0.01116613  0.78862097]]
# Episode 100: Total Reward = 428.94964825618433, Accuracy = 0.88, Confidence Probability = 0.27, Time of Classification = 0.1038 seconds
# Q-table:
# [[-0.04050073 -0.03109621 -0.05002412 -0.02209833  0.79996583]
#  [-0.02842679 -0.03106923 -0.02729085 -0.02516892  0.79221901]
#  [-0.0240138  -0.02939202 -0.02338536 -0.0239962   0.82091754]
#  ...
#  [-0.03188634 -0.03947854 -0.01719725 -0.01627186  0.74908289]
#  [-0.03126318 -0.01124129 -0.03322413 -0.03216481  0.76458689]
#  [-0.0181624  -0.01771143 -0.01558422 -0.01116613  0.7967942 ]]
# [4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#  4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#  4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#  4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#  4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#  4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#  4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#  4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#  4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#  4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#  4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14312\4035046444.py in <module>
#     126                 # Drop in the NaN values in the 'Beat_Number' column
#     127                 #print(df['Beat_Number'].isnull().sum())
# --> 128                 df = df.dropna(subset=['Beat_Number'])
#     129
#     130                 # Check if the 'Beat_Number' column exists in the dataframe
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    6009             check = indices == -1
#    6010             if check.any():
# -> 6011                 raise KeyError(np.array(subset)[check].tolist())
#    6012             agg_obj = self.take(indices, axis=agg_axis)
#    6013
#
# KeyError: ['Beat_Number']
